# %% [markdown]
# 1. What are the benefits of including roles in the programmes?
#
# Answer:
#
#
# 2. When does the code in a function run: when it's specified or when it's called?
#
# Answer: Codes in a function runs and produces output at the time when the function is called.
#
#
# 3. What statement causes a feature to be created?
#
# Answer:
#
#
# 4. What is the distinction between a function and a call to a function?
#
# Answer: A function is a block of codes where it is defined to perform a special task, howsoever it will perform that particular task only when it is called.
#
#
# 5. In a Python application, how many global scopes are there? How many local scopes are there?
#
# Answer: There are in total 4 types of scopes in Python:
# 1.Global
# 2.Local
# 3.BuiltIn
# 4.NonLocal
#
#
# 6. When a function call returns, what happens to variables in the local scope?
#
# Answer: The local variable gets executed only when the function is called. Once the function returns the local variable gets deactivated thus defining the scope of local variable limited to function block.
#
#
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Answer: When a function is called it return a value. If return is followed by an expreesion, it returns a value once the expression is executed depending on the position of return statement. As the return statement is reached the programme is left at that point.
#
#
# 8. What is the return value of a call to a function that does not have a return statement?
#
# Answer: returns none
#
#
# 9. How do you make a function variable refer to the global variable?
#
# Answer: Using Keyword "global".
# ex. global
#
#
# 10. What data form does None belong to?
# Answer:
#
#
# 11. What does the sentence import areallyourpetsnamederic do?
#
#
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
#
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Answer: Interrupting the kernel and restarting it after rectifying the statement
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Answer: try block let us test the block of code for errors on the error hand except clause handles the error
